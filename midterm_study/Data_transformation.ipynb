# %%
import pandas as pd 
import numpy as np

# %%
data = [[104, "PUTNAM", 15, "Yes"],
     [197, "LEXINGTON", 3, "No"],
       ["NaN","LEXINGTON","n/a" , "No"],
       [201, "BERKELEY", 2, 12],
       [203, "BERKELEY", 3, "Yes"],
       [207, "BERKELEY", "NaN", "Yes"],
       ["NaN", "LEXINGTON", 2, "NaN"],
        [213, "TREMONT", -5, "Yes"],
        [217, "TREMONT", "na", "Yes"]]

cols = ['street_number', 'street_name', 'num_bedrooms', 'owner_occupied']

df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
#   street_number street_name num_bedrooms owner_occupied
# 0           104      PUTNAM           15            Yes
# 1           197   LEXINGTON            3             No
# 2           NaN   LEXINGTON          n/a             No
# 3           201    BERKELEY            2             12
# 4           203    BERKELEY            3            Yes
# 5           207    BERKELEY          NaN            Yes
# 6           NaN   LEXINGTON            2            NaN
# 7           213     TREMONT           -5            Yes
# 8           217     TREMONT           na            Yes

# %%
df['num_bedrooms']= df['num_bedrooms'].apply(lambda x: np.nan if isinstance(x, str) else x)

# %%
df
# Out:
#   street_number street_name  num_bedrooms owner_occupied
# 0           104      PUTNAM          15.0            Yes
# 1           197   LEXINGTON           3.0             No
# 2           NaN   LEXINGTON           NaN             No
# 3           201    BERKELEY           2.0            NaN
# 4           203    BERKELEY           3.0            Yes
# 5           207    BERKELEY           NaN            Yes
# 6           NaN   LEXINGTON           2.0            NaN
# 7           213     TREMONT           5.0            Yes
# 8           217     TREMONT           NaN            Yes

# %%
df['num_bedrooms'] = df['num_bedrooms'].abs()

# %%
df
# Out:
#   street_number street_name  num_bedrooms owner_occupied
# 0           104      PUTNAM          15.0            Yes
# 1           197   LEXINGTON           3.0             No
# 2           NaN   LEXINGTON           NaN             No
# 3           201    BERKELEY           2.0             12
# 4           203    BERKELEY           3.0            Yes
# 5           207    BERKELEY           NaN            Yes
# 6           NaN   LEXINGTON           2.0            NaN
# 7           213     TREMONT           5.0            Yes
# 8           217     TREMONT           NaN            Yes

# %%
df['owner_occupied'] = df['owner_occupied'].apply(lambda x: x if not isinstance(x, int) else np.nan)

# %%
df
# Out:
#   street_number street_name  num_bedrooms owner_occupied
# 0           104      PUTNAM          15.0            Yes
# 1           197   LEXINGTON           3.0             No
# 2           NaN   LEXINGTON           NaN             No
# 3           201    BERKELEY           2.0            NaN
# 4           203    BERKELEY           3.0            Yes
# 5           207    BERKELEY           NaN            Yes
# 6           NaN   LEXINGTON           2.0            NaN
# 7           213     TREMONT           5.0            Yes
# 8           217     TREMONT           NaN            Yes

# %%
df.fillna('')
# Out:
#   street_number street_name num_bedrooms owner_occupied
# 0           104      PUTNAM           15            Yes
# 1           197   LEXINGTON            3             No
# 2           NaN   LEXINGTON                          No
# 3           201    BERKELEY            2
# 4           203    BERKELEY            3            Yes
# 5           207    BERKELEY                         Yes
# 6           NaN   LEXINGTON            2            NaN
# 7           213     TREMONT            5            Yes
# 8           217     TREMONT                         Yes

# %%
df.dtypes
# Out:
# street_number     object
# street_name       object
# num_bedrooms      object
# owner_occupied    object
# dtype: object

# %%
df.replace('NaN', np.NaN, inplace = True)

# %%
df
# Out:
#    street_number street_name num_bedrooms owner_occupied
# 0          104.0      PUTNAM           15            Yes
# 1          197.0   LEXINGTON            3             No
# 2            NaN   LEXINGTON          n/a             No
# 3          201.0    BERKELEY            2             12
# 4          203.0    BERKELEY            3            Yes
# 5          207.0    BERKELEY          NaN            Yes
# 6            NaN   LEXINGTON            2            NaN
# 7          213.0     TREMONT           -5            Yes
# 8          217.0     TREMONT           na            Yes

# %%
cols = ['street_number','num_bedrooms']
df[cols]= df[cols].applymap(lambda x: x if not isinstance(x, str) else np.nan)

# %%
df
# Out:
#    street_number street_name  num_bedrooms owner_occupied
# 0          104.0      PUTNAM          15.0            Yes
# 1          197.0   LEXINGTON           3.0             No
# 2            NaN   LEXINGTON           NaN             No
# 3          201.0    BERKELEY           2.0             12
# 4          203.0    BERKELEY           3.0            Yes
# 5          207.0    BERKELEY           NaN            Yes
# 6            NaN   LEXINGTON           2.0            NaN
# 7          213.0     TREMONT          -5.0            Yes
# 8          217.0     TREMONT           NaN            Yes

# %%
df.fillna('')
# Out:
#   street_number street_name num_bedrooms owner_occupied
# 0           104      PUTNAM           15            Yes
# 1           197   LEXINGTON            3             No
# 2                 LEXINGTON                          No
# 3           201    BERKELEY            2             12
# 4           203    BERKELEY            3            Yes
# 5           207    BERKELEY                         Yes
# 6                 LEXINGTON            2
# 7           213     TREMONT           -5            Yes
# 8           217     TREMONT                         Yes

# %%
df['num_bedrooms'] = df['num_bedrooms'].abs()

# %%
df
# Out:
#    street_number street_name  num_bedrooms owner_occupied
# 0          104.0      PUTNAM          15.0            Yes
# 1          197.0   LEXINGTON           3.0             No
# 2            NaN   LEXINGTON           NaN             No
# 3          201.0    BERKELEY           2.0             12
# 4          203.0    BERKELEY           3.0            Yes
# 5          207.0    BERKELEY           NaN            Yes
# 6            NaN   LEXINGTON           2.0            NaN
# 7          213.0     TREMONT           5.0            Yes
# 8          217.0     TREMONT           NaN            Yes

# %%
df.fillna('')
# Out:
#   street_number street_name num_bedrooms owner_occupied
# 0           104      PUTNAM           15            Yes
# 1           197   LEXINGTON            3             No
# 2                 LEXINGTON                          No
# 3           201    BERKELEY            2             12
# 4           203    BERKELEY            3            Yes
# 5           207    BERKELEY                         Yes
# 6                 LEXINGTON            2
# 7           213     TREMONT            5            Yes
# 8           217     TREMONT                         Yes

# %%
cols = ['owner_occupied']
df[cols]= df[cols].applymap(lambda x: x if not isinstance(x, int) else np.nan)

# %%
df
# Out:
#    street_number street_name  num_bedrooms owner_occupied
# 0          104.0      PUTNAM          15.0            Yes
# 1          197.0   LEXINGTON           3.0             No
# 2            NaN   LEXINGTON           NaN             No
# 3          201.0    BERKELEY           2.0            NaN
# 4          203.0    BERKELEY           3.0            Yes
# 5          207.0    BERKELEY           NaN            Yes
# 6            NaN   LEXINGTON           2.0            NaN
# 7          213.0     TREMONT           5.0            Yes
# 8          217.0     TREMONT           NaN            Yes

# %%
df.dropna(how='all')
# Out:
#    street_number street_name  num_bedrooms owner_occupied
# 0          104.0      PUTNAM          15.0            Yes
# 1          197.0   LEXINGTON           3.0             No
# 2            NaN   LEXINGTON           NaN             No
# 3          201.0    BERKELEY           2.0            NaN
# 4          203.0    BERKELEY           3.0            Yes
# 5          207.0    BERKELEY           NaN            Yes
# 6            NaN   LEXINGTON           2.0            NaN
# 7          213.0     TREMONT           5.0            Yes
# 8          217.0     TREMONT           NaN            Yes
